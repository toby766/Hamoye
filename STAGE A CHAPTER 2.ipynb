# %%
import numpy as np
import pandas as pd
foodagric = pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv?raw=true.csv', encoding = 'latin-1')

# %%
foodagric
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
foodagric.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
foodagric.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
foodagric.groupby('Y2014')['Y2014'].count()
foodagric[['Y2014']] = foodagric[['Y2014']].fillna(value='0')

# %%
foodagric.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014              0
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
foodagric.groupby('Y2014')['Y2014'].count()
# Out:
# Y2014
# -1796.0        1
# -1631.0        1
# -849.0         2
# -838.0         1
# -685.0         1
#             ...
# 98094.0        1
# 108756.0       1
# 109593.0       1
# 176405.0       1
# 0           1589
# Name: Y2014, Length: 4494, dtype: int64

# %%
foodagric1 = foodagric.iloc[0:15000].reset_index(drop=True)
print(foodagric1)
# Out:
#        Area Code           Area  Item Code                     Item  \
# 0              4        Algeria       2501               Population
# 1              4        Algeria       2501               Population
# 2              4        Algeria       2901              Grand Total
# 3              4        Algeria       2901              Grand Total
# 4              4        Algeria       2901              Grand Total
# ...          ...            ...        ...                      ...
# 14995        107  Côte d'Ivoire       2848  Milk - Excluding Butter
# 14996        107  Côte d'Ivoire       2848  Milk - Excluding Butter
# 14997        107  Côte d'Ivoire       2848  Milk - Excluding Butter
# 14998        107  Côte d'Ivoire       2848  Milk - Excluding Butter
# 14999        107  Côte d'Ivoire       2848  Milk - Excluding Butter
#
#        Element Code                                 Element             Unit  \
# ...

# %%
foodagric2 = foodagric.iloc[15000:].reset_index(drop=True)
print(foodagric2)
# Out:
#        Area Code           Area  Item Code                     Item  \
# 0            107  Côte d'Ivoire       2848  Milk - Excluding Butter
# 1            107  Côte d'Ivoire       2960            Fish, Seafood
# 2            107  Côte d'Ivoire       2960            Fish, Seafood
# 3            107  Côte d'Ivoire       2960            Fish, Seafood
# 4            107  Côte d'Ivoire       2960            Fish, Seafood
# ...          ...            ...        ...                      ...
# 45938        181       Zimbabwe       2899            Miscellaneous
# 45939        181       Zimbabwe       2899            Miscellaneous
# 45940        181       Zimbabwe       2899            Miscellaneous
# 45941        181       Zimbabwe       2899            Miscellaneous
# 45942        181       Zimbabwe       2899            Miscellaneous
#
#        Element Code                                 Element             Unit  \
# ...

# %%
len(foodagric)
# Out:
# 60943

# %%
assert len(foodagric) == (len(foodagric1)+len(foodagric2))

# %%
pd.merge(foodagric1, foodagric2, how='inner')
# Out:
# Empty DataFrame
# Columns: [Area Code, Area, Item Code, Item, Element Code, Element, Unit, Y2014, Y2015, Y2016, Y2017, Y2018]
# Index: []

# %%
pd.merge(foodagric1, foodagric2, how='outer')
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit    Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.0
# ...

# %%
pd.merge(foodagric1, foodagric2, how='left')
# Out:
#        Area Code           Area  Item Code                     Item  \
# 0              4        Algeria       2501               Population
# 1              4        Algeria       2501               Population
# 2              4        Algeria       2901              Grand Total
# 3              4        Algeria       2901              Grand Total
# 4              4        Algeria       2901              Grand Total
# ...          ...            ...        ...                      ...
# 14995        107  Côte d'Ivoire       2848  Milk - Excluding Butter
# 14996        107  Côte d'Ivoire       2848  Milk - Excluding Butter
# 14997        107  Côte d'Ivoire       2848  Milk - Excluding Butter
# 14998        107  Côte d'Ivoire       2848  Milk - Excluding Butter
# 14999        107  Côte d'Ivoire       2848  Milk - Excluding Butter
#
#        Element Code                                 Element             Unit  \
# ...

# %%
pd.concat([foodagric, data_to_concat]).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14968/1162774254.py in <module>
# ----> 1 pd.concat([foodagric, data_to_concat]).reset_index(drop=True)
#
# NameError: name 'data_to_concat' is not defined

# %%
foodagric.duplicated().any()
# Out:
# False
